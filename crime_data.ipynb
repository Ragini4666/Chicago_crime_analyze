# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# !pip install pandas openpyxl

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
d1 =pd.read_excel("C:/Users/ragin/Downloads/Crime_Data.xlsx")

# %%
d1.head()
# Out:
#          ID Case Number                Date                      Block IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE  560
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE  110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD  110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST  620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
d1.shape
# Out:
# (549999, 22)

# %%
d1.describe()
# Out:
#                  ID                           Date           Beat  \
# count  5.499990e+05                         549999  549999.000000
# mean   5.748380e+06  2009-10-05 02:55:46.740996096    1200.364957
# min    6.340000e+02            2001-01-01 00:00:00     111.000000
# 25%    1.477682e+06     2001-04-21 02:04:25.500000     621.000000
# 50%    1.651346e+06            2001-08-04 19:00:00    1113.000000
# 75%    1.327660e+07            2023-11-07 23:00:00    1813.000000
# max    1.348547e+07            2024-05-30 00:00:00    2535.000000
# std    5.669909e+06                            NaN     712.157469
#
#             District           Ward  Community Area  X Coordinate  \
# count  549999.000000  213674.000000   215093.000000  5.430870e+05
# mean       11.339984      23.064659       36.755436  1.164788e+06
# min         1.000000       1.000000        1.000000  0.000000e+00
# 25%         6.000000      10.000000       22.000000  1.153708e+06
# ...

# %%
d1.describe(include=object)
# Out:
#        Case Number             Block    IUCR Primary Type Description  \
# count       549999            549999  549999       549999      549999
# unique      549434             51020     356           34         449
# top       HZ140230  100XX W OHARE ST     460        THEFT      SIMPLE
# freq             6              1475   66750       112771       95252
#
#        Location Description  FBI Code                       Location
# count                548326    549999                         543087
# unique                  210        27                         278640
# top                  STREET         6  (41.976200173, -87.905312411)
# freq                 166056    112771                           1324

# %%
d1.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1673
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  datetime64[ns]
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %% [markdown]
# ### FILL THE CATEGORICAL VALUES THROUGH MODE VALUE

# %%
#fill NAN values =>mode function
d1['Location Description'] = d1['Location Description'].fillna(d1['Location Description'].mode())

# %%
d1['Location Description'].isnull().sum()
# Out:
# 0

# %%
d1['Location'] =d1['Location'].fillna(d1['Location'].mode())

# %%
d1['Location'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### FILL THE CONTINUOUS VALUES THROUGH MEAN VALUE

# %%
d1['Longitude'] =d1['Longitude'].fillna(d1['Longitude'].mean())
d1['Latitude'] = d1['Latitude'].fillna(d1['Latitude'].mean())
d1['Ward'] = d1['Ward'].fillna(d1['Ward'].mean())
d1['Community Area'] = d1['Community Area'].fillna(d1['Community Area'].mean())

# %%
d1['X Coordinate'] = d1['X Coordinate'].fillna(d1['X Coordinate'].mean())
d1['Y Coordinate'] = d1['Y Coordinate'].fillna(d1['Y Coordinate'].mean())

# %%
d1.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# Loaction                0
# dtype: int64

# %%
sns.countplot(data = d1,x='Arrest')
plt.title("distribution of Arrest")
plt.show()

# %%
fig=d1.hist(figsize=(18,18))

# %%
d1.head()
# Out:
#          ID Case Number                Date                      Block IUCR  \
# 0   5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE  560
# 1     25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE  110
# 2     26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD  110
# 3  13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST  620
# 4  13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE  454
#
#   Primary Type                                        Description  \
# 0      ASSAULT                                             SIMPLE
# 1     HOMICIDE                                FIRST DEGREE MURDER
# 2     HOMICIDE                                FIRST DEGREE MURDER
# 3     BURGLARY                                     UNLAWFUL ENTRY
# 4      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
d1.tail()
# Out:
#              ID Case Number                Date                    Block  \
# 549994  1715153     G516233 2001-08-27 23:00:00     036XX S LAKE PARK AV
# 549995  1799889     G625392 2001-10-16 16:30:00       065XX S STEWART AV
# 549996  1769834     G583569 2001-09-29 05:35:00  031XX N CENTRAL PARK AV
# 549997  1788327     G610965 2001-09-12 09:05:00        065XX S CICERO AV
# 549998  1810693     G627247 2001-10-18 17:34:00     053XX W FERDINAND ST
#
#         IUCR         Primary Type                     Description  \
# 549994  4387        OTHER OFFENSE     VIOLATE ORDER OF PROTECTION
# 549995   610             BURGLARY                  FORCIBLE ENTRY
# 549996   460              BATTERY                          SIMPLE
# 549997   910  MOTOR VEHICLE THEFT                      AUTOMOBILE
# 549998  2092            NARCOTICS  SOLICIT NARCOTICS ON PUBLICWAY
#
#        Location Description  Arrest  Domestic  ...       Ward  Community Area  \
# ...

# %%
d1 = d1.drop(columns=['Loaction'])

# %%
d1
# Out:
#               ID Case Number                Date                      Block  \
# 0        5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE
# 1          25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE
# 2          26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD
# 3       13279676    JG507211 2023-11-09 07:30:00           019XX W BYRON ST
# 4       13274752    JG501049 2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# ...          ...         ...                 ...                        ...
# 549994   1715153     G516233 2001-08-27 23:00:00       036XX S LAKE PARK AV
# 549995   1799889     G625392 2001-10-16 16:30:00         065XX S STEWART AV
# 549996   1769834     G583569 2001-09-29 05:35:00    031XX N CENTRAL PARK AV
# 549997   1788327     G610965 2001-09-12 09:05:00          065XX S CICERO AV
# 549998   1810693     G627247 2001-10-18 17:34:00       053XX W FERDINAND ST
#
#         IUCR         Primary Type  \
# ...

# %%
data = d1.to_csv("crimedata.csv", index=False)

# %%
data = pd.read_csv("crimedata.csv")

# %%
data
# Out:
#               ID Case Number                 Date                      Block  \
# 0        5741943    HN549294  2007-08-25 09:22:18         074XX N ROGERS AVE
# 1          25953    JE240540  2021-05-24 15:06:00        020XX N LARAMIE AVE
# 2          26038    JE279849  2021-06-26 09:24:00      062XX N MC CORMICK RD
# 3       13279676    JG507211  2023-11-09 07:30:00           019XX W BYRON ST
# 4       13274752    JG501049  2023-11-12 07:59:00  086XX S COTTAGE GROVE AVE
# ...          ...         ...                  ...                        ...
# 549994   1715153     G516233  2001-08-27 23:00:00       036XX S LAKE PARK AV
# 549995   1799889     G625392  2001-10-16 16:30:00         065XX S STEWART AV
# 549996   1769834     G583569  2001-09-29 05:35:00    031XX N CENTRAL PARK AV
# 549997   1788327     G610965  2001-09-12 09:05:00          065XX S CICERO AV
# 549998   1810693     G627247  2001-10-18 17:34:00       053XX W FERDINAND ST
#
#         IUCR         Primary Type  \
# ...
